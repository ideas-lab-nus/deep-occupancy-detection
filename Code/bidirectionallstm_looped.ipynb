# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from matplotlib.patches import Rectangle
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.metrics import r2_score

# %% [markdown]
# # Set model parameters

# %%
# Number of timesteps we want to look into the future based on the past 
# timesteps.
FORECAST_STEP = 1
# Number of past timesteps we want to use to predict the future.
WINDOW_SIZE = 5
TRAIN_RATIO = 0.8
EPOCHS = 10
BATCH_SIZE = 16
FEATURE_SELECTION = True
NUM_FEATURES = 5

# %% [markdown]
# # Load data

# %%
#Import Train Dataset
dir_path = "drive/MyDrive/ROBOD/"
# Beehub, DIC, ER1, ER2, IRC
room_name = "IRC"
filename = "combined_{}_imputed.csv".format(room_name)

# %% [markdown]
# # Data preprocessing

# %%
model_results = {}
for num_features in list(np.arange(1, 5)) + list(np.arange(5, 65, 5)):
  for i in range(5):
    data = pd.read_csv(dir_path + filename)

    # Extract hour information
    data[["date","time","utc_offset"]] = data["timestamp"].str.split(' ',expand=True)
    data[["hour","minute"]] = data["time"].str.split(':',expand=True)
    data = pd.concat([data, pd.get_dummies(data["hour"], dtype=float, prefix="hour")], axis=1)

    # Drop redundant columns
    redundant_cols = ["date", "time", "utc_offset", "minute", "occupant_presence", "hour"]
    data = data.drop(columns=redundant_cols)

    # Shift "occupancy_count" to the first column
    original_col_seq = list(data.columns)
    original_col_seq.remove("occupant_count")
    original_col_seq.remove("timestamp")
    data = data[["timestamp", "occupant_count"] + original_col_seq]
    
    #Choosing Training variables 
    cols = list(data)[1:]

    #Converting all variables into float
    df_for_training = data[cols].astype(float)
    df_for_training.head()

    if FEATURE_SELECTION:
      feature_selection_score = pd.read_csv(dir_path + "/Feature Selection and Importance/combined_feature_selection_{}.csv".format(room_name))
      top_n_features = feature_selection_score["feature"].tolist()[:num_features]
      df_for_training = df_for_training[["occupant_count"] + top_n_features]

    # perform feature scaling
    scaler = StandardScaler()
    scaler = scaler.fit(df_for_training)
    df_for_training_scaled = scaler.transform(df_for_training)

    # perform train test split
    X = []
    Y = []

    #Reformat input data into a shape: (n_samples x timesteps x n_features)
    for i in range(WINDOW_SIZE, len(df_for_training)-FORECAST_STEP+1):
      X.append(df_for_training_scaled[i-WINDOW_SIZE:i, :])
      Y.append(df_for_training_scaled[i+FORECAST_STEP-1, 0])

    trainX = X[:int(len(X) * TRAIN_RATIO)]
    testX = X[int(len(X) * TRAIN_RATIO):]
    trainY = Y[:int(len(Y) * TRAIN_RATIO)]
    testY = Y[int(len(Y) * TRAIN_RATIO):]
        
    trainX, trainY = np.array(trainX), np.array(trainY).reshape(-1,1)
    testX, testY = np.array(testX), np.array(testY).reshape(-1,1)

    input_size = trainX.shape[2]-1

    # Creating the model
    model = Sequential()
    model.add(Bidirectional(
        LSTM(32,
            activation="relu", 
            return_sequences=True)))
    model.add(Bidirectional(
        LSTM(32,
            activation="relu", 
            return_sequences=True)))
    model.add(Bidirectional(
        LSTM(32,
            activation="relu", 
            return_sequences=False)))
    model.add(Dense(1))

    model.compile(
        loss=tf.keras.losses.mse,
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
        metrics=["mae"]
    )

    # fit the model
    history = model.fit(trainX, 
                        trainY, 
                        epochs=EPOCHS, 
                        batch_size=BATCH_SIZE, 
                        validation_split=0.1, 
                        verbose=1)
    
    # Compare actual and predicted test values
    y_preds = model.predict(testX)

    # Inverse transformation
    prediction_copies = np.repeat(y_preds, df_for_training.shape[1], axis=-1)
    test_predictions = scaler.inverse_transform(prediction_copies)[:,0]

    testY_copies = np.repeat(testY, df_for_training.shape[1], axis=-1)
    testY = scaler.inverse_transform(testY_copies)[:,0]

    test_results = pd.DataFrame(data={'Test Predictions':np.round(test_predictions), 
                                      'Actuals':testY})

    ## Evaluate the model predictions
    mae = tf.metrics.mean_absolute_error(y_true=testY, y_pred=test_predictions)  
    rmse = tf.sqrt(tf.metrics.mean_squared_error(y_true=testY, y_pred=test_predictions))
    r2 = r2_score(y_true=testY, y_pred=test_predictions)
  
    if input_size not in model_results:
      model_results[input_size] = {"MAE":[], "RMSE":[], "R2":[]}
    model_results[input_size]["MAE"].append(mae.numpy())
    model_results[input_size]["RMSE"].append(rmse.numpy())
    model_results[input_size]["R2"].append(r2)
    
    del model
# Out:
# Epoch 1/10
# 609/609 [==============================] - 28s 19ms/step - loss: 0.1404 - mae: 0.1980 - val_loss: 0.0919 - val_mae: 0.1544
# Epoch 2/10
# 609/609 [==============================] - 8s 13ms/step - loss: 0.0609 - mae: 0.1309 - val_loss: 0.0354 - val_mae: 0.0831
# Epoch 3/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0572 - mae: 0.1244 - val_loss: 0.0316 - val_mae: 0.0888
# Epoch 4/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0550 - mae: 0.1213 - val_loss: 0.0312 - val_mae: 0.0942
# Epoch 5/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0538 - mae: 0.1197 - val_loss: 0.0358 - val_mae: 0.0827
# Epoch 6/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0530 - mae: 0.1166 - val_loss: 0.0299 - val_mae: 0.0827
# Epoch 7/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0534 - mae: 0.1169 - val_loss: 0.0373 - val_mae: 0.1094
# Epoch 8/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0515 - mae: 0.1136 - val_loss: 0.0483 - val_mae: 0.1094
# Epoch 9/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0521 - mae: 0.1167 - val_loss: 0.0318 - val_mae: 0.0781
# Epoch 10/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0516 - mae: 0.1132 - val_loss: 0.0301 - val_mae: 0.0791
# Epoch 1/10
# 609/609 [==============================] - 16s 15ms/step - loss: 0.1190 - mae: 0.1811 - val_loss: 0.0361 - val_mae: 0.1029
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0587 - mae: 0.1307 - val_loss: 0.0412 - val_mae: 0.1322
# Epoch 3/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0555 - mae: 0.1243 - val_loss: 0.0339 - val_mae: 0.0825
# Epoch 4/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0541 - mae: 0.1222 - val_loss: 0.0311 - val_mae: 0.0816
# Epoch 5/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0545 - mae: 0.1205 - val_loss: 0.0506 - val_mae: 0.1139
# Epoch 6/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0541 - mae: 0.1210 - val_loss: 0.0424 - val_mae: 0.1010
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0527 - mae: 0.1170 - val_loss: 0.0313 - val_mae: 0.0739
# Epoch 8/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0516 - mae: 0.1134 - val_loss: 0.0275 - val_mae: 0.0667
# Epoch 9/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0519 - mae: 0.1137 - val_loss: 0.0293 - val_mae: 0.0825
# Epoch 10/10
# 609/609 [==============================] - 8s 14ms/step - loss: 0.0520 - mae: 0.1128 - val_loss: 0.0359 - val_mae: 0.1166
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1150 - mae: 0.1803 - val_loss: 0.0422 - val_mae: 0.1027
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0596 - mae: 0.1285 - val_loss: 0.0470 - val_mae: 0.1084
# Epoch 3/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0580 - mae: 0.1266 - val_loss: 0.0361 - val_mae: 0.0984
# Epoch 4/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0557 - mae: 0.1234 - val_loss: 0.0366 - val_mae: 0.0942
# Epoch 5/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0550 - mae: 0.1217 - val_loss: 0.0324 - val_mae: 0.0739
# Epoch 6/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0537 - mae: 0.1186 - val_loss: 0.0310 - val_mae: 0.0816
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0527 - mae: 0.1178 - val_loss: 0.0285 - val_mae: 0.0700
# Epoch 8/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0529 - mae: 0.1173 - val_loss: 0.0286 - val_mae: 0.0712
# Epoch 9/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0528 - mae: 0.1157 - val_loss: 0.0299 - val_mae: 0.0830
# Epoch 10/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0503 - mae: 0.1119 - val_loss: 0.0292 - val_mae: 0.0747
# Epoch 1/10
# 609/609 [==============================] - 17s 16ms/step - loss: 0.1084 - mae: 0.1757 - val_loss: 0.0455 - val_mae: 0.1142
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0579 - mae: 0.1314 - val_loss: 0.0517 - val_mae: 0.1058
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0565 - mae: 0.1254 - val_loss: 0.0383 - val_mae: 0.1055
# Epoch 4/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0529 - mae: 0.1178 - val_loss: 0.0327 - val_mae: 0.0886
# Epoch 5/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0538 - mae: 0.1209 - val_loss: 0.0269 - val_mae: 0.0765
# Epoch 6/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0519 - mae: 0.1168 - val_loss: 0.0307 - val_mae: 0.0763
# Epoch 7/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0531 - mae: 0.1189 - val_loss: 0.0320 - val_mae: 0.1018
# Epoch 8/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0524 - mae: 0.1163 - val_loss: 0.0284 - val_mae: 0.0811
# Epoch 9/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0512 - mae: 0.1131 - val_loss: 0.0487 - val_mae: 0.1097
# Epoch 10/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0525 - mae: 0.1145 - val_loss: 0.0322 - val_mae: 0.1159
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1189 - mae: 0.1811 - val_loss: 0.2712 - val_mae: 0.1150
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0600 - mae: 0.1318 - val_loss: 0.0408 - val_mae: 0.1232
# Epoch 3/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0555 - mae: 0.1241 - val_loss: 0.0318 - val_mae: 0.0792
# Epoch 4/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0526 - mae: 0.1201 - val_loss: 0.0316 - val_mae: 0.0907
# Epoch 5/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0541 - mae: 0.1212 - val_loss: 0.0403 - val_mae: 0.1089
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0528 - mae: 0.1168 - val_loss: 0.0474 - val_mae: 0.0992
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0527 - mae: 0.1196 - val_loss: 0.0428 - val_mae: 0.0940
# Epoch 8/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0514 - mae: 0.1168 - val_loss: 0.0847 - val_mae: 0.1063
# Epoch 9/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0513 - mae: 0.1136 - val_loss: 0.0347 - val_mae: 0.0932
# Epoch 10/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0510 - mae: 0.1150 - val_loss: 0.1014 - val_mae: 0.0876
# Epoch 1/10
# 609/609 [==============================] - 17s 16ms/step - loss: 0.1157 - mae: 0.1824 - val_loss: 0.0379 - val_mae: 0.0987
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0604 - mae: 0.1317 - val_loss: 0.0432 - val_mae: 0.1403
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0573 - mae: 0.1256 - val_loss: 0.0350 - val_mae: 0.0984
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0548 - mae: 0.1210 - val_loss: 0.0302 - val_mae: 0.0809
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0558 - mae: 0.1226 - val_loss: 0.0327 - val_mae: 0.0937
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0524 - mae: 0.1168 - val_loss: 0.0278 - val_mae: 0.0799
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0525 - mae: 0.1167 - val_loss: 0.0332 - val_mae: 0.0871
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0528 - mae: 0.1159 - val_loss: 0.0283 - val_mae: 0.0784
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0521 - mae: 0.1160 - val_loss: 0.0366 - val_mae: 0.0891
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0520 - mae: 0.1160 - val_loss: 0.0296 - val_mae: 0.0765
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1178 - mae: 0.1870 - val_loss: 0.0674 - val_mae: 0.1620
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0597 - mae: 0.1310 - val_loss: 0.0364 - val_mae: 0.0912
# Epoch 3/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0550 - mae: 0.1233 - val_loss: 0.0410 - val_mae: 0.1123
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0544 - mae: 0.1213 - val_loss: 0.0298 - val_mae: 0.0756
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0540 - mae: 0.1196 - val_loss: 0.0376 - val_mae: 0.1242
# Epoch 6/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0541 - mae: 0.1195 - val_loss: 0.0362 - val_mae: 0.0869
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0528 - mae: 0.1160 - val_loss: 0.0316 - val_mae: 0.0951
# Epoch 8/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0521 - mae: 0.1157 - val_loss: 0.0293 - val_mae: 0.0803
# Epoch 9/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0510 - mae: 0.1140 - val_loss: 0.0340 - val_mae: 0.0957
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0520 - mae: 0.1149 - val_loss: 0.0363 - val_mae: 0.0934
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1215 - mae: 0.1871 - val_loss: 0.1658 - val_mae: 0.1142
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0615 - mae: 0.1372 - val_loss: 0.0297 - val_mae: 0.0747
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0565 - mae: 0.1263 - val_loss: 0.0529 - val_mae: 0.1152
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0550 - mae: 0.1221 - val_loss: 0.0314 - val_mae: 0.0966
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0561 - mae: 0.1232 - val_loss: 0.0404 - val_mae: 0.0957
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0524 - mae: 0.1155 - val_loss: 0.0350 - val_mae: 0.0888
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0530 - mae: 0.1177 - val_loss: 0.0365 - val_mae: 0.0994
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0523 - mae: 0.1164 - val_loss: 0.0392 - val_mae: 0.1051
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0519 - mae: 0.1168 - val_loss: 0.0318 - val_mae: 0.0824
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0518 - mae: 0.1140 - val_loss: 0.0476 - val_mae: 0.1268
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1105 - mae: 0.1792 - val_loss: 0.0423 - val_mae: 0.1175
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0590 - mae: 0.1287 - val_loss: 0.0411 - val_mae: 0.0920
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0571 - mae: 0.1256 - val_loss: 0.0321 - val_mae: 0.0778
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0542 - mae: 0.1190 - val_loss: 0.0345 - val_mae: 0.0871
# Epoch 5/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0542 - mae: 0.1179 - val_loss: 0.0421 - val_mae: 0.1147
# Epoch 6/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0524 - mae: 0.1165 - val_loss: 0.0324 - val_mae: 0.0860
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0541 - mae: 0.1178 - val_loss: 0.0303 - val_mae: 0.0738
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0513 - mae: 0.1140 - val_loss: 0.0504 - val_mae: 0.1523
# Epoch 9/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0518 - mae: 0.1162 - val_loss: 0.0349 - val_mae: 0.1072
# Epoch 10/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0513 - mae: 0.1145 - val_loss: 0.0313 - val_mae: 0.0990
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1174 - mae: 0.1866 - val_loss: 0.0415 - val_mae: 0.1077
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0617 - mae: 0.1345 - val_loss: 0.0382 - val_mae: 0.0794
# Epoch 3/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0568 - mae: 0.1252 - val_loss: 0.0394 - val_mae: 0.0943
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0555 - mae: 0.1238 - val_loss: 0.0331 - val_mae: 0.0931
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0540 - mae: 0.1191 - val_loss: 0.0355 - val_mae: 0.1155
# Epoch 6/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0536 - mae: 0.1180 - val_loss: 0.0309 - val_mae: 0.0806
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0529 - mae: 0.1169 - val_loss: 0.0415 - val_mae: 0.0843
# Epoch 8/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0512 - mae: 0.1138 - val_loss: 0.0389 - val_mae: 0.0867
# Epoch 9/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0522 - mae: 0.1160 - val_loss: 0.0334 - val_mae: 0.0862
# Epoch 10/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0527 - mae: 0.1170 - val_loss: 0.0343 - val_mae: 0.1060
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1187 - mae: 0.1871 - val_loss: 0.0410 - val_mae: 0.0976
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0615 - mae: 0.1350 - val_loss: 0.0358 - val_mae: 0.0978
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0563 - mae: 0.1251 - val_loss: 0.0314 - val_mae: 0.0711
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0551 - mae: 0.1237 - val_loss: 0.0309 - val_mae: 0.0826
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0531 - mae: 0.1182 - val_loss: 0.0416 - val_mae: 0.0833
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0535 - mae: 0.1190 - val_loss: 0.0327 - val_mae: 0.0847
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0511 - mae: 0.1132 - val_loss: 0.0338 - val_mae: 0.0949
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0519 - mae: 0.1150 - val_loss: 0.0319 - val_mae: 0.0805
# Epoch 9/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0513 - mae: 0.1135 - val_loss: 0.0499 - val_mae: 0.0978
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0518 - mae: 0.1159 - val_loss: 0.0335 - val_mae: 0.0839
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1534 - mae: 0.1962 - val_loss: 0.0601 - val_mae: 0.1130
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0621 - mae: 0.1320 - val_loss: 0.0721 - val_mae: 0.1131
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0559 - mae: 0.1240 - val_loss: 0.0431 - val_mae: 0.1093
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0548 - mae: 0.1208 - val_loss: 0.0400 - val_mae: 0.0985
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0538 - mae: 0.1196 - val_loss: 0.0583 - val_mae: 0.1212
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0527 - mae: 0.1170 - val_loss: 0.0399 - val_mae: 0.0953
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0519 - mae: 0.1151 - val_loss: 0.0336 - val_mae: 0.0794
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0518 - mae: 0.1146 - val_loss: 0.0385 - val_mae: 0.0732
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0512 - mae: 0.1132 - val_loss: 0.0381 - val_mae: 0.0951
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0511 - mae: 0.1118 - val_loss: 0.0350 - val_mae: 0.0855
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1234 - mae: 0.1931 - val_loss: 0.0485 - val_mae: 0.0949
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0627 - mae: 0.1361 - val_loss: 0.0396 - val_mae: 0.0913
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0572 - mae: 0.1272 - val_loss: 0.0378 - val_mae: 0.1169
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0568 - mae: 0.1253 - val_loss: 0.0362 - val_mae: 0.0895
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0542 - mae: 0.1222 - val_loss: 0.0302 - val_mae: 0.0869
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0522 - mae: 0.1182 - val_loss: 0.0395 - val_mae: 0.1036
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0518 - mae: 0.1159 - val_loss: 0.0370 - val_mae: 0.1109
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0530 - mae: 0.1182 - val_loss: 0.0301 - val_mae: 0.0663
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0516 - mae: 0.1141 - val_loss: 0.0461 - val_mae: 0.0902
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0509 - mae: 0.1139 - val_loss: 0.0396 - val_mae: 0.0829
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1348 - mae: 0.1955 - val_loss: 0.0521 - val_mae: 0.1316
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0590 - mae: 0.1332 - val_loss: 0.0595 - val_mae: 0.1263
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0583 - mae: 0.1292 - val_loss: 0.0524 - val_mae: 0.1488
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0543 - mae: 0.1238 - val_loss: 0.0423 - val_mae: 0.1139
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0525 - mae: 0.1183 - val_loss: 0.0426 - val_mae: 0.1003
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0531 - mae: 0.1188 - val_loss: 0.0318 - val_mae: 0.0906
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0526 - mae: 0.1165 - val_loss: 0.0311 - val_mae: 0.0725
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0515 - mae: 0.1147 - val_loss: 0.0303 - val_mae: 0.0850
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0507 - mae: 0.1135 - val_loss: 0.0476 - val_mae: 0.1006
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0520 - mae: 0.1152 - val_loss: 0.0366 - val_mae: 0.0811
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1177 - mae: 0.1853 - val_loss: 0.0494 - val_mae: 0.0969
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0596 - mae: 0.1306 - val_loss: 0.0588 - val_mae: 0.1142
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0578 - mae: 0.1285 - val_loss: 0.0361 - val_mae: 0.0987
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0550 - mae: 0.1219 - val_loss: 0.0405 - val_mae: 0.0792
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0547 - mae: 0.1216 - val_loss: 0.0427 - val_mae: 0.1216
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0539 - mae: 0.1199 - val_loss: 0.0347 - val_mae: 0.1007
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0532 - mae: 0.1201 - val_loss: 0.0605 - val_mae: 0.1412
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0531 - mae: 0.1175 - val_loss: 0.0292 - val_mae: 0.0731
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0523 - mae: 0.1171 - val_loss: 0.0371 - val_mae: 0.0976
# Epoch 10/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0512 - mae: 0.1125 - val_loss: 0.0277 - val_mae: 0.0686
# Epoch 1/10
# 609/609 [==============================] - 17s 16ms/step - loss: 0.1195 - mae: 0.1955 - val_loss: 0.0968 - val_mae: 0.1298
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0640 - mae: 0.1376 - val_loss: 0.0513 - val_mae: 0.1450
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0586 - mae: 0.1303 - val_loss: 0.0373 - val_mae: 0.0842
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0567 - mae: 0.1282 - val_loss: 0.0551 - val_mae: 0.1121
# Epoch 5/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0530 - mae: 0.1204 - val_loss: 0.0404 - val_mae: 0.1003
# Epoch 6/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0526 - mae: 0.1178 - val_loss: 0.0292 - val_mae: 0.0779
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0532 - mae: 0.1187 - val_loss: 0.0331 - val_mae: 0.1003
# Epoch 8/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0511 - mae: 0.1142 - val_loss: 0.0354 - val_mae: 0.0927
# Epoch 9/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0509 - mae: 0.1143 - val_loss: 0.0538 - val_mae: 0.1035
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0518 - mae: 0.1158 - val_loss: 0.0320 - val_mae: 0.0777
# Epoch 1/10
# 609/609 [==============================] - 17s 16ms/step - loss: 0.1293 - mae: 0.1948 - val_loss: 0.0451 - val_mae: 0.1291
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0608 - mae: 0.1323 - val_loss: 0.0482 - val_mae: 0.0910
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0586 - mae: 0.1311 - val_loss: 0.0433 - val_mae: 0.1178
# Epoch 4/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0564 - mae: 0.1260 - val_loss: 0.0363 - val_mae: 0.0894
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0539 - mae: 0.1204 - val_loss: 0.0400 - val_mae: 0.0911
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0542 - mae: 0.1215 - val_loss: 0.0415 - val_mae: 0.1048
# Epoch 7/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0528 - mae: 0.1183 - val_loss: 0.0379 - val_mae: 0.0933
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0522 - mae: 0.1169 - val_loss: 0.0341 - val_mae: 0.0887
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0517 - mae: 0.1170 - val_loss: 0.0511 - val_mae: 0.0981
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0502 - mae: 0.1135 - val_loss: 0.0416 - val_mae: 0.0934
# Epoch 1/10
# 609/609 [==============================] - 17s 16ms/step - loss: 0.1191 - mae: 0.1873 - val_loss: 0.0665 - val_mae: 0.1154
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0618 - mae: 0.1349 - val_loss: 0.0449 - val_mae: 0.1173
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0581 - mae: 0.1301 - val_loss: 0.0357 - val_mae: 0.0875
# Epoch 4/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0547 - mae: 0.1233 - val_loss: 0.0400 - val_mae: 0.0853
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0542 - mae: 0.1223 - val_loss: 0.0310 - val_mae: 0.0773
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0536 - mae: 0.1197 - val_loss: 0.0392 - val_mae: 0.1067
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0531 - mae: 0.1203 - val_loss: 0.0434 - val_mae: 0.0972
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0515 - mae: 0.1135 - val_loss: 0.0348 - val_mae: 0.0986
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0509 - mae: 0.1128 - val_loss: 0.0369 - val_mae: 0.0881
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0509 - mae: 0.1130 - val_loss: 0.0495 - val_mae: 0.1149
# Epoch 1/10
# 609/609 [==============================] - 17s 16ms/step - loss: 0.1338 - mae: 0.1965 - val_loss: 0.0542 - val_mae: 0.1330
# Epoch 2/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0622 - mae: 0.1345 - val_loss: 0.0432 - val_mae: 0.1059
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0586 - mae: 0.1318 - val_loss: 0.0368 - val_mae: 0.0954
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0546 - mae: 0.1227 - val_loss: 0.0522 - val_mae: 0.1454
# Epoch 5/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0556 - mae: 0.1237 - val_loss: 0.0413 - val_mae: 0.1117
# Epoch 6/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0527 - mae: 0.1209 - val_loss: 0.0512 - val_mae: 0.1029
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0517 - mae: 0.1170 - val_loss: 0.0372 - val_mae: 0.0940
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0529 - mae: 0.1181 - val_loss: 0.0579 - val_mae: 0.1430
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0509 - mae: 0.1143 - val_loss: 0.0474 - val_mae: 0.1140
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0508 - mae: 0.1135 - val_loss: 0.0451 - val_mae: 0.1020
# Epoch 1/10
# 609/609 [==============================] - 18s 16ms/step - loss: 0.1226 - mae: 0.1907 - val_loss: 0.0629 - val_mae: 0.1145
# Epoch 2/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0620 - mae: 0.1360 - val_loss: 0.0484 - val_mae: 0.1232
# Epoch 3/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0587 - mae: 0.1296 - val_loss: 0.0415 - val_mae: 0.1233
# Epoch 4/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0552 - mae: 0.1257 - val_loss: 0.0393 - val_mae: 0.0965
# Epoch 5/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0542 - mae: 0.1228 - val_loss: 0.0448 - val_mae: 0.0949
# Epoch 6/10
# 609/609 [==============================] - 9s 14ms/step - loss: 0.0542 - mae: 0.1205 - val_loss: 0.0498 - val_mae: 0.1287
# Epoch 7/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0523 - mae: 0.1168 - val_loss: 0.0408 - val_mae: 0.1058
# Epoch 8/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0522 - mae: 0.1170 - val_loss: 0.0480 - val_mae: 0.0953
# Epoch 9/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0516 - mae: 0.1144 - val_loss: 0.0440 - val_mae: 0.0923
# Epoch 10/10
# 609/609 [==============================] - 9s 15ms/step - loss: 0.0509 - mae: 0.1128 - val_loss: 0.0411 - val_mae: 0.0914

# %%
results_dict = {}
for k, v in model_results.items():
  results_dict[k] = [sum(v["MAE"])/len(v["MAE"]), 
                     max(v["MAE"]), 
                     min(v["MAE"]), 
                     sum(v["RMSE"])/len(v["RMSE"]), 
                     max(v["RMSE"]), 
                     min(v["RMSE"]),
                     sum(v["R2"])/len(v["R2"]), 
                     max(v["R2"]), 
                     min(v["R2"])]

results_df = pd.DataFrame.from_dict(results_dict, orient='index', columns=["MAE_mean","MAE_max","MAE_min",
                                                                           "RMSE_mean","RMSE_max","RMSE_min",
                                                                           "R2_mean","R2_max","R2_min"])
results_df = results_df.rename_axis('num_features').reset_index()
results_df.head()
# Out:
#    num_features  MAE_mean   MAE_max   MAE_min  RMSE_mean  RMSE_max  RMSE_min  \
# 0             1  0.192686  0.305562  0.120255   0.358520  0.415122  0.322585
# 1             2  0.220578  0.306693  0.144539   0.379505  0.458320  0.329750
# 2             3  0.152853  0.195477  0.114017   0.342727  0.386346  0.315236
# 3             4  0.149656  0.176587  0.126135   0.330410  0.344171  0.320041
#
#     R2_mean    R2_max    R2_min
# 0  0.888466  0.910979  0.852581
# 1  0.874694  0.906981  0.820304
# 2  0.898902  0.914989  0.872311
# 3  0.906512  0.912378  0.898667

# %%
results_df.to_csv(dir_path + "Model Results/bidirectional_lstm_performance_vs_num_features_{}.csv".format(room_name), index=False)

# %%
room_name = "IRC"
results_df = pd.read_csv(dir_path + "Model Results/bidirectional_lstm_performance_vs_num_features_{}.csv".format(room_name))

space_type_mapping = {"Beehub":"Office",
                      "DIC":"Office",
                      "ER1":"Lecture Room",
                      "ER2":"Lecture Room",
                      "IRC":"Library"}

plt.figure(figsize=(10, 8))
plt.rcParams.update({'font.size': 23})

# Plot the MAE results
plt.plot(results_df["num_features"], results_df["MAE_mean"], color="blue", label="MAE")
# Plot the confidence interval
plt.fill_between(results_df["num_features"], results_df["MAE_min"], results_df["MAE_max"], color="blue", alpha=0.1)

# Plot the RMSE results
plt.plot(results_df["num_features"], results_df["RMSE_mean"], color="orange", label="RMSE")
# Plot the confidence interval
plt.fill_between(results_df["num_features"], results_df["RMSE_min"], results_df["RMSE_max"], color="orange", alpha=0.1)

# Indicate model performance based on RFECV 
rfecv_result = pd.read_csv(dir_path + "/Feature Selection and Importance/combined_feature_selection_{}.csv".format(room_name))
num_feature_selected_rfecv = len(rfecv_result[rfecv_result["ranking"]==1])
plt.axvline(x=num_feature_selected_rfecv, 
            ymin=0, ymax=5, color='black', linestyle="dashed", label="RFECV")

# Indicate model performance based on proposed feature selection algorithm
best_performance_idx = 0
for i in range(1, len(results_df)):
  if results_df.loc[i, "MAE_mean"] > results_df.loc[best_performance_idx, "MAE_mean"]:
    break
  else:
    best_performance_idx = i
plt.axvline(x=results_df.loc[best_performance_idx, "num_features"],
            ymin=0, ymax=5, color='#8b0000', linestyle="dashed", label="Proposed \nAlgorithm")

plt.legend(prop={'size': 20})
plt.xlabel("Number of Features")
plt.ylabel("Error")
xticks = [int(tick) for tick in results_df["num_features"].tolist() 
          if (tick % 5 == 0) or (tick == results_df.loc[best_performance_idx, 
                                                        "num_features"])]
# xticks.append(num_feature_selected_rfecv)
xticks.sort()
plt.xticks(ticks=xticks, labels=xticks)
plt.title("Bi-LSTM")
plt.savefig(dir_path + "Figures/bidirectional_lstm_performance_vs_num_features_{}.png".format(room_name), 
            dpi=600, bbox_inches="tight")
plt.show()
